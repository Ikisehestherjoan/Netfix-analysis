# %% [markdown]
# # THIS IS A NETFLIX DATASET WHICH WAS GOTTEN FROM KAGGLE .

# %%
#IMPORT THE DATASET
import pandas as pd
import seaborn as sns
net=pd.read_csv(r'C:\Users\hp\Desktop\prjport\netflix.csv')

# %%
net
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
#some basic information about the dataset

# %% [markdown]
# #head ,5 top rows

# %%
net.head(5)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %% [markdown]
# #tail

# %%
net.tail(5)
# Out:
#      Show_Id Category                                    Title     Director  \
# 7784   s7783    Movie                                     Zozo  Josef Fares
# 7785   s7784    Movie                                   Zubaan  Mozez Singh
# 7786   s7785    Movie                        Zulu Man in Japan          NaN
# 7787   s7786  TV Show                    Zumbo's Just Desserts          NaN
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS     Sam Dunn
#
#                                                    Cast  \
# 7784  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7785  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7786                                            Nasty C
# 7787                         Adriano Zumbo, Rachel Khoo
# 7788                                                NaN
#
#                                                 Country        Release_Date  \
# 7784  Sweden, Czech Republic, United Kingdom, Denmar...    October 19, 2020
# ...

# %% [markdown]
# #shape

# %%
net.shape
# Out:
# (7789, 11)

# %% [markdown]
# #size

# %%
net.size
# Out:
# 85679

# %% [markdown]
# #columns

# %%
net.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %% [markdown]
# #info

# %%
net.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %% [markdown]
# dtypes object datatypes

# %%
net.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %% [markdown]
# #Get the duolicates and remove them

# %%
net[net.duplicated()]#displays duplicated values
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %% [markdown]
# #remove the duplicates

# %%
net.drop_duplicates(inplace=True)#inplace is used to permanently remove the duplicate

# %%
 #check if duplicates still exists

# %%
net[net.duplicated()]#displays duplicated values
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description]
# Index: []

# %%
net.shape#A decrement in the rows occured by 2
# Out:
# (7787, 11)

# %% [markdown]
# # displaying the null values

# %%
net.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
net.isnull()
# Out:
#       Show_Id  Category  Title  Director   Cast  Country  Release_Date  \
# 0       False     False  False      True  False    False         False
# 1       False     False  False     False  False    False         False
# 2       False     False  False     False  False    False         False
# 3       False     False  False     False  False    False         False
# 4       False     False  False     False  False    False         False
# ...       ...       ...    ...       ...    ...      ...           ...
# 7784    False     False  False     False  False    False         False
# 7785    False     False  False     False  False    False         False
# 7786    False     False  False      True  False     True         False
# 7787    False     False  False      True  False    False         False
# 7788    False     False  False     False   True    False         False
#
#       Rating  Duration   Type  Description
# 0      False     False  False        False
# ...

# %% [markdown]
# counting of null function in each column

# %%
net.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %% [markdown]
# displaying the null values

# %%
sns.heatmap(net.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# #In  order to confirm if a perticular items is in dataset,we use "is in"

# %%
net.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
net["Title"]
# Out:
# 0                                            3%
# 1                                         07:19
# 2                                         23:59
# 3                                             9
# 4                                            21
#                          ...
# 7784                                       Zozo
# 7785                                     Zubaan
# 7786                          Zulu Man in Japan
# 7787                      Zumbo's Just Desserts
# 7788    ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
# Name: Title, Length: 7787, dtype: object

# %%
net[net["Title"].isin(["Zulu Man in Japan"])]
# Out:
#      Show_Id Category              Title Director     Cast Country  \
# 7786   s7785    Movie  Zulu Man in Japan      NaN  Nasty C     NaN
#
#             Release_Date Rating Duration  \
# 7786  September 25, 2020  TV-MA   44 min
#
#                                                    Type  \
# 7786  Documentaries, International Movies, Music & M...
#
#                                             Description
# 7786  In this documentary, South African rapper Nast...

# %% [markdown]
# #Str.contains can also be used to display a particular record

# %%
net[net["Title"].str.contains("Zulu Man in Japan")]
# Out:
#      Show_Id Category              Title Director     Cast Country  \
# 7786   s7785    Movie  Zulu Man in Japan      NaN  Nasty C     NaN
#
#             Release_Date Rating Duration  \
# 7786  September 25, 2020  TV-MA   44 min
#
#                                                    Type  \
# 7786  Documentaries, International Movies, Music & M...
#
#                                             Description
# 7786  In this documentary, South African rapper Nast...

# %%
net['p']=pd.to_datetime(net["Release_Date"])

# %%
net
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
net['p'].dt.year.value_counts()
# Out:
# 2019.0    2153
# 2020.0    2009
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2008.0       2
# 2009.0       2
# 2010.0       1
# Name: p, dtype: int64

# %%
net['p'].dt.month.value_counts()
# Out:
# 12.0    833
# 10.0    785
# 1.0     757
# 11.0    738
# 3.0     669
# 9.0     619
# 8.0     618
# 4.0     601
# 7.0     600
# 5.0     543
# 6.0     542
# 2.0     472
# Name: p, dtype: int64

# %%
net['p'].dt.day.value_counts()
# Out:
# 1.0     2069
# 15.0     644
# 31.0     274
# 2.0      247
# 16.0     240
# 20.0     219
# 10.0     213
# 5.0      207
# 19.0     203
# 8.0      190
# 22.0     185
# 30.0     182
# 25.0     180
# 18.0     178
# 26.0     174
# 28.0     172
# 21.0     172
# 6.0      165
# 7.0      162
# 14.0     161
# 12.0     156
# 27.0     153
# 13.0     153
# 17.0     153
# 4.0      151
# 23.0     138
# 24.0     136
# 29.0     130
# 3.0      127
# 11.0     123
# 9.0      120
# Name: p, dtype: int64

# %% [markdown]
# #Displaying total movies in month and year bar graph

# %%
net['p'].dt.year.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
net['p'].dt.month.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# #COUNTING THE NUMBER OF MOVIES AND  TV SHOW IN THE DATA SET
# IN ORDER TO ACHIEVE THIS THE GROUPBY COMES IN PLAY

# %%
net.groupby('Category').Category.count()
# Out:
# Category
# Movie      5377
# TV Show    2410
# Name: Category, dtype: int64

# %% [markdown]
# #GROUPING BY COUNTRY

# %%
net.groupby('Country').Country.count()
# Out:
# Country
# Argentina                                              50
# Argentina, Brazil, France, Poland, Germany, Denmark     1
# Argentina, Chile                                        1
# Argentina, Chile, Peru                                  1
# Argentina, France                                       1
#                                                        ..
# Venezuela                                               1
# Venezuela, Colombia                                     1
# Vietnam                                                 5
# West Germany                                            1
# Zimbabwe                                                1
# Name: Country, Length: 681, dtype: int64

# %% [markdown]
# #ploting of  the category

# %%
net.groupby('Category').Category.count().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Category'>

# %%
sns.countplot(net['Category'])
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Category', ylabel='count'>

# %%
net['Year']=net['p'].dt.year

# %%
net.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %% [markdown]
# # DISPLAYING ALL MOVIES REALEASED IN 2018

# %%
net[(net['Category']=='Movie')  &  (net['Year']==2018)]
# Out:
#      Show_Id Category                     Title          Director  \
# 2         s3    Movie                     23:59      Gilbert Chan
# 17       s18    Movie                    22-Jul   Paul Greengrass
# 19       s20    Movie                       '89               NaN
# 20       s21    Movie      ​​Kuch Bheege Alfaaz              Onir
# 21       s22    Movie              ​Goli Soda 2      Vijay Milton
# ...      ...      ...                       ...               ...
# 7765   s7764    Movie                     Zenda    Avadhoot Gupte
# 7770   s7769    Movie  Zindagi Kitni Haseen Hay     Anjum Shahzad
# 7773   s7772    Movie                      Zion        Floyd Russ
# 7778   s7777    Movie                  Zokkomon  Satyajit Bhatkal
# 7782   s7781    Movie                       Zoo      Shlok Sharma
#
#                                                    Cast  \
# 2     Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 17    Anders Danielsen Lie, Jon Øigarden, Jonas Stra...
# ...

# %% [markdown]
# #dispalyingTv shows from United States

# %%
net[(net['Category']=='TV Show')  &  (net['Country']=='United States')]['Title']
# Out:
# 26                                (Un)Well
# 29                                #blackAF
# 53                              100 Humans
# 63                          13 Reasons Why
# 64      13 Reasons Why: Beyond the Reasons
#                        ...
# 7714                          Yo-Kai Watch
# 7723                                   You
# 7732                          You vs. Wild
# 7737                        Young & Hungry
# 7757                              Z Nation
# Name: Title, Length: 705, dtype: object

# %% [markdown]
# #Counting Tv shows from United States

# %%
net[(net['Category']=='TV Show')  &  (net['Country']=='United States')]['Country'].value_counts()
# Out:
# United States    705
# Name: Country, dtype: int64

# %%
net.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %% [markdown]
# #displaying  Top 12 Directors with the highest number of movies

# %%
net['Director'].value_counts().head(12)
# Out:
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Youssef Chahine           12
# Martin Scorsese           12
# Steven Spielberg          10
# David Dhawan               9
# Hakan Algül                8
# Lance Bangs                8
# Kunle Afolayan             8
# Name: Director, dtype: int64

# %% [markdown]
# #SHOWING ALL RECORDA WHERE CATEGORY IS TV SHOW AND action type OR CLOUNTRY IS UNITED STATES

# %%
net.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description          p    Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0

# %%
net[(net['Category']=='Movie') & (net['Type']=='Dramas')]
# Out:
#      Show_Id Category                       Title           Director  \
# 4         s5    Movie                          21     Robert Luketic
# 7         s8    Movie                         187     Kevin Reynolds
# 170     s171    Movie                A Family Man      Mark Williams
# 232     s233    Movie  A Stoning in Fulham County      Larry Elikann
# 295     s296    Movie          Across Grace Alley      Ralph Macchio
# ...      ...      ...                         ...                ...
# 7417   s7416    Movie                      Victor  Brandon Dickerson
# 7422   s7421    Movie                     Villain   Philip Barantini
# 7449   s7448    Movie                         VS.           Ed Lilly
# 7465   s7464    Movie                   Wakefield      Robin Swicord
# 7480   s7479    Movie                   War Horse   Steven Spielberg
#
#                                                    Cast  \
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...

# %%
 net[net['Country'] =='United States']
# Out:
#      Show_Id Category                       Title         Director  \
# 3         s4    Movie                           9      Shane Acker
# 4         s5    Movie                          21   Robert Luketic
# 7         s8    Movie                         187   Kevin Reynolds
# 10       s11    Movie                        1922     Zak Hilditch
# 14       s15    Movie                        3022       John Suits
# ...      ...      ...                         ...              ...
# 7760   s7759    Movie  Zack and Miri Make a Porno      Kevin Smith
# 7773   s7772    Movie                        Zion       Floyd Russ
# 7776   s7775    Movie                      Zodiac    David Fincher
# 7780   s7779    Movie                  Zombieland  Ruben Fleischer
# 7783   s7782    Movie                        Zoom     Peter Hewitt
#
#                                                    Cast        Country  \
# 3     Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# ...

# %%
net[(net['Category']=='Movie') & (net['Type']=='Dramas') | (net['Country'] =='United States') ]
# Out:
#      Show_Id Category                       Title         Director  \
# 3         s4    Movie                           9      Shane Acker
# 4         s5    Movie                          21   Robert Luketic
# 7         s8    Movie                         187   Kevin Reynolds
# 10       s11    Movie                        1922     Zak Hilditch
# 14       s15    Movie                        3022       John Suits
# ...      ...      ...                         ...              ...
# 7760   s7759    Movie  Zack and Miri Make a Porno      Kevin Smith
# 7773   s7772    Movie                        Zion       Floyd Russ
# 7776   s7775    Movie                      Zodiac    David Fincher
# 7780   s7779    Movie                  Zombieland  Ruben Fleischer
# 7783   s7782    Movie                        Zoom     Peter Hewitt
#
#                                                    Cast        Country  \
# 3     Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# ...

# %% [markdown]
# #REMOVING ALL MISSING VALUES

# %%
net_new=net.dropna()

# %%
net_new.head()
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
# 5      s6  TV Show     46        Serdar Akar
#
#                                                 Cast        Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# 5  Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...         Turkey
#
#         Release_Date Rating  Duration  \
# 1  December 23, 2016  TV-MA    93 min
# 2  December 20, 2018      R    78 min
# 3  November 16, 2017  PG-13    80 min
# 4    January 1, 2020  PG-13   123 min
# 5       July 1, 2017  TV-MA  1 Season
#
# ...

# %% [markdown]
# #Displayin records for Zion Clark

# %%
net_new[net_new['Cast'].str.contains('Zion Clark')]
# Out:
#      Show_Id Category Title    Director        Cast        Country  \
# 7773   s7772    Movie  Zion  Floyd Russ  Zion Clark  United States
#
#          Release_Date Rating Duration                          Type  \
# 7773  August 10, 2018  TV-PG   12 min  Documentaries, Sports Movies
#
#                                             Description          p    Year
# 7773  Born without legs and stuck in foster care for... 2018-08-10  2018.0

# %%
#displaying records for Erdal Beşikçioğlu

# %%
net_new[net_new['Cast'].str.contains('Erdal Beşikçioğlu')]
# Out:
#   Show_Id Category Title     Director  \
# 5      s6  TV Show    46  Serdar Akar
#
#                                                 Cast Country  Release_Date  \
# 5  Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...  Turkey  July 1, 2017
#
#   Rating  Duration                                             Type  \
# 5  TV-MA  1 Season  International TV Shows, TV Dramas, TV Mysteries
#
#                                          Description          p    Year
# 5  A genetics professor experiments with a treatm... 2017-07-01  2017.0

# %% [markdown]
# #DISPLAYING THE VARIOUS RATING IN THE DATA SET

# %%
net["Rating"].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-G', 'TV-PG', 'NR', 'PG', 'G',
#        'TV-Y7', 'TV-Y', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
net['Rating'].nunique()
# Out:
# 14

# %% [markdown]
# #DISPLAYING MOVIE RATING  OF TV-PG IN INDIA

# %%
net[(net['Category']=='Movie') & (net['Rating']=='TV-PG')   & (net['Country']=='India')]
# Out:
#      Show_Id Category                 Title              Director  \
# 78       s79    Movie              2 States       Abhishek Varman
# 266     s267    Movie    Aajcha Divas Majha  Chandrakant Kulkarni
# 268     s269    Movie            Aalorukkam          V C Abhilash
# 277     s278    Movie              Abby Sen           Atanu Ghosh
# 300     s301    Movie        Action Replayy   Vipul Amrutlal Shah
# ...      ...      ...                   ...                   ...
# 7264   s7263    Movie               Tukaram  Chandrakant Kulkarni
# 7525   s7524    Movie               Welcome          Anees Bazmee
# 7567   s7566    Movie       What the Jatt!!            Saket Behl
# 7576   s7575    Movie  What's Your Raashee?    Ashutosh Gowariker
# 7699   s7698    Movie   Yanda Kartavya Aahe          Kedar Shinde
#
#                                                    Cast Country  \
# 78    Alia Bhatt, Arjun Kapoor, Ronit Roy, Amrita Si...   India
# ...

# %%
#HOW MANY TV SHOW  GOT THE TV RATINGS TV-14 AFTER 2017

# %%
net[(net['Category']=='TV Show') & (net['Rating']=='TV-14')   & (net['Year']>2017)].shape
# Out:
# (28, 13)

# %%
#WHAT IS THE MAXIMUM DURATION OF A MOVIE/SHOW ON NETFLIX

# %%
net.head()
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
# 5      s6  TV Show     46        Serdar Akar
#
#                                                 Cast        Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# 5  Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...         Turkey
#
#         Release_Date Rating  Duration  \
# 1  December 23, 2016  TV-MA    93 min
# 2  December 20, 2018      R    78 min
# 3  November 16, 2017  PG-13    80 min
# 4    January 1, 2020  PG-13   123 min
# 5       July 1, 2017  TV-MA  1 Season
#
# ...

# %%
net.Duration.nunique()
# Out:
# 195

# %%
net.Duration.unique()
# Out:
# array(['93 min', '78 min', '80 min', '123 min', '1 Season', '95 min',
#        '119 min', '118 min', '143 min', '103 min', '89 min', '91 min',
#        '149 min', '144 min', '124 min', '110 min', '128 min', '117 min',
#        '100 min', '99 min', '102 min', '104 min', '105 min', '125 min',
#        '81 min', '97 min', '106 min', '107 min', '87 min', '109 min',
#        '101 min', '90 min', '113 min', '114 min', '130 min', '94 min',
#        '140 min', '135 min', '82 min', '70 min', '92 min', '164 min',
#        '83 min', '116 min', '84 min', '86 min', '120 min', '96 min',
#        '126 min', '75 min', '129 min', '77 min', '137 min', '148 min',
#        '121 min', '122 min', '176 min', '85 min', '22 min', '68 min',
#        '111 min', '29 min', '142 min', '168 min', '59 min', '108 min',
#        '44 min', '26 min', '156 min', '98 min', '57 min', '150 min',
#        '133 min', '115 min', '154 min', '127 min', '146 min', '136 min',
# ...

# %%
net[['mins','Dim']]=net['Duration'].str.split(' ', expand=True)

# %%
net
# Out:
#      Show_Id Category       Title           Director  \
# 1         s2    Movie       07:19  Jorge Michel Grau
# 2         s3    Movie       23:59       Gilbert Chan
# 3         s4    Movie           9        Shane Acker
# 4         s5    Movie          21     Robert Luketic
# 5         s6  TV Show          46        Serdar Akar
# ...      ...      ...         ...                ...
# 7780   s7779    Movie  Zombieland    Ruben Fleischer
# 7782   s7781    Movie         Zoo       Shlok Sharma
# 7783   s7782    Movie        Zoom       Peter Hewitt
# 7784   s7783    Movie        Zozo        Josef Fares
# 7785   s7784    Movie      Zubaan        Mozez Singh
#
#                                                    Cast  \
# 1     Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2     Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3     Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...

# %%
net.mins.max()
# Out:
# '99'

# %%
net.mins.min()
# Out:
# '1'

# %% [markdown]
# Sorting of the years in ascending and descending order

# %%
net.sort_values(by='Year')
# Out:
#      Show_Id Category                              Title  \
# 7115   s7114    Movie               To and From New York
# 5766   s5766    Movie                           Splatter
# 3248   s3249    Movie            Just Another Love Story
# 3840   s3841    Movie        Mad Ron's Prevues from Hell
# 3221   s3222    Movie             Joseph: King of Dreams
# ...      ...      ...                                ...
# 1426   s1427    Movie  Cloudy with a Chance of Meatballs
# 1739   s1740    Movie        Dhobi Ghat (Mumbai Diaries)
# 7553   s7552    Movie          What Happened to Mr. Cha?
# 2479   s2480    Movie                          Good Hair
# 3237   s3238    Movie                      Julie & Julia
#
#                            Director  \
# 7115           Sorin Dan Mihalcescu
# 5766                      Joe Dante
# 3248                   Ole Bornedal
# 3840                     Jim Monaco
# 3221  Rob LaDuca, Robert C. Ramirez
# ...                             ...
# ...

# %%
net.sort_values(by='Year', ascending=False)
# Out:
#      Show_Id Category                        Title  \
# 2269   s2270    Movie                   Fred Claus
# 2349   s2350    Movie                    Gangaajal
# 6248   s6248    Movie           The Creative Brain
# 1673   s1674    Movie                  Death of Me
# 7147   s7146    Movie  Tony Parker: The Final Shot
# ...      ...      ...                          ...
# 2041   s2042    Movie                Even the Rain
# 3840   s3841    Movie  Mad Ron's Prevues from Hell
# 3248   s3249    Movie      Just Another Love Story
# 5766   s5766    Movie                     Splatter
# 7115   s7114    Movie         To and From New York
#
#                              Director  \
# 2269                     David Dobkin
# 2349                      Prakash Jha
# 6248  Jennifer Beamish, Toby Trackman
# 1673              Darren Lynn Bousman
# 7147                    Florent Bodin
# ...                               ...
# 2041                    Icíar Bollaín
# ...
